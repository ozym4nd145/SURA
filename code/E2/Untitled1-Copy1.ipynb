# %%
from __future__ import division
from __future__ import print_function
from __future__ import absolute_import

import os
import sys
from coco_eval.pycocotools.coco import COCO
from coco_eval.pycocoevalcap.eval import COCOEvalCap
import configuration
import argparse
import pandas as pd
import matplotlib.pyplot as plt

def get_score(ref_filename,gen_filename,data_config):
    ref_file = os.path.join(data_config["result_dir"],ref_filename)
    gen_file = os.path.join(data_config["result_dir"],gen_filename)

    if not os.path.isfile(ref_file):
        print("%s not found in %s\nExiting" %(ref_filename,data_config["result_dir"]))
        sys.exit()

    if not os.path.isfile(gen_file):
        print("%s not found in %s\nExiting" %(gen_filename,data_config["result_dir"]))
        sys.exit()

    # create coco object and cocoRes object
    coco = COCO(ref_file)
    cocoRes = coco.loadRes(gen_file)

    # create cocoEval object by taking coco and cocoRes
    cocoEval = COCOEvalCap(coco, cocoRes)

    # evaluate on a subset of images by setting
    # cocoEval.params['image_id'] = cocoRes.getImgIds()
    # please remove this line when evaluating the full validation set
    cocoEval.params['image_id'] = cocoRes.getImgIds()

    # evaluate results
    cocoEval.evaluate()
    return cocoEval

# %%
a = models

# %%
b = scores

# %%
c = list(zip(a,b))

# %%
c
# Out:
# [('model-9044',
#   {'Bleu_1': 0.773583009044845,
#    'Bleu_2': 0.606476588296607,
#    'Bleu_3': 0.45833960541263,
#    'Bleu_4': 0.3345407243301598,
#    'CIDEr': 0.39354468702456996,
#    'METEOR': 0.2633545680936823,
#    'ROUGE_L': 0.57281490858146022}),
#  ('model-10480',
#   {'Bleu_1': 0.7706949127221532,
#    'Bleu_2': 0.6045242287618017,
#    'Bleu_3': 0.4562077672626666,
#    'Bleu_4': 0.3325241314728971,
#    'CIDEr': 0.38329952112853244,
#    'METEOR': 0.2618892772050306,
#    'ROUGE_L': 0.57023677243255622}),
#  ('model-16052',
#   {'Bleu_1': 0.759605776517704,
#    'Bleu_2': 0.5982799861552048,
#    'Bleu_3': 0.45468495158250594,
#    'Bleu_4': 0.33298947160677017,
#    'CIDEr': 0.36782288811148217,
#    'METEOR': 0.2569874055651692,
#    'ROUGE_L': 0.56667069495692823}),
#  ('model-6408',
#   {'Bleu_1': 0.7748908525751322,
#    'Bleu_2': 0.6194949713371428,
#    'Bleu_3': 0.4761867168325123,
#    'Bleu_4': 0.3541422957813222,
#    'CIDEr': 0.39364337012527068,
#    'METEOR': 0.2610190019115988,
#    'ROUGE_L': 0.58039308675592527}),
#  ('model-20360',
#   {'Bleu_1': 0.7535207939836672,
#    'Bleu_2': 0.589583546959259,
#    'Bleu_3': 0.44581478751570874,
#    'Bleu_4': 0.3258163839519824,
#    'CIDEr': 0.37132785561604098,
#    'METEOR': 0.2536114541233807,
#    'ROUGE_L': 0.56251681573022083}),
#  ('model-4972',
#   {'Bleu_1': 0.779589121730603,
#    'Bleu_2': 0.6238867472210415,
#    'Bleu_3': 0.4785936660108123,
#    'Bleu_4': 0.35535147170722614,
#    'CIDEr': 0.40537140081271417,
#    'METEOR': 0.2632998138311796,
#    'ROUGE_L': 0.58300532431025143}),
#  ('model-5572',
#   {'Bleu_1': 0.776807160398031,
#    'Bleu_2': 0.6178921039156946,
#    'Bleu_3': 0.4721289409561074,
#    'Bleu_4': 0.3502802086899458,
#    'CIDEr': 0.39814671812225005,
#    'METEOR': 0.2623074642829495,
#    'ROUGE_L': 0.58083935386965391}),
#  ('model-12816',
#   {'Bleu_1': 0.7695285219495414,
#    'Bleu_2': 0.6092477193764696,
#    'Bleu_3': 0.46584844692796107,
#    'Bleu_4': 0.3443591273362451,
#    'CIDEr': 0.39198254460880055,
#    'METEOR': 0.2600121545229725,
#    'ROUGE_L': 0.57527835656638115}),
#  ('model-2936',
#   {'Bleu_1': 0.7700672179658002,
#    'Bleu_2': 0.6149940071476686,
#    'Bleu_3': 0.47565646215587715,
#    'Bleu_4': 0.3557744679067562,
#    'CIDEr': 0.37956650308675643,
#    'METEOR': 0.2563373740201271,
#    'ROUGE_L': 0.58426787497844501}),
#  ('model-4672',
#   {'Bleu_1': 0.7705102847685613,
#    'Bleu_2': 0.6129827379323538,
#    'Bleu_3': 0.4707173365318577,
#    'Bleu_4': 0.34696339624212713,
#    'CIDEr': 0.38960583423542072,
#    'METEOR': 0.2573141443468951,
#    'ROUGE_L': 0.5760575387473339}),
#  ('model-18624',
#   {'Bleu_1': 0.7561194348532949,
#    'Bleu_2': 0.5888118446573547,
#    'Bleu_3': 0.44322522308150186,
#    'Bleu_4': 0.32237237650607564,
#    'CIDEr': 0.36806319917805635,
#    'METEOR': 0.25445004941019483,
#    'ROUGE_L': 0.56016867142417293}),
#  ('model-8744',
#   {'Bleu_1': 0.7727656955309871,
#    'Bleu_2': 0.6138386514764923,
#    'Bleu_3': 0.4685540607152158,
#    'Bleu_4': 0.34397928456915855,
#    'CIDEr': 0.39441689561535598,
#    'METEOR': 0.2597721410117236,
#    'ROUGE_L': 0.57490994451312827}),
#  ('model-16588',
#   {'Bleu_1': 0.7539916463349127,
#    'Bleu_2': 0.5809424930059556,
#    'Bleu_3': 0.4325164172176445,
#    'Bleu_4': 0.3104851885905382,
#    'CIDEr': 0.37006342235891909,
#    'METEOR': 0.2568352010296076,
#    'ROUGE_L': 0.55847965434897517}),
#  ('model-13716',
#   {'Bleu_1': 0.7702934658355158,
#    'Bleu_2': 0.6081135910036822,
#    'Bleu_3': 0.46268429698076247,
#    'Bleu_4': 0.341065107948712,
#    'CIDEr': 0.39180356998518023,
#    'METEOR': 0.2630280680511232,
#    'ROUGE_L': 0.57304028092872317}),
#  ('model-600',
#   {'Bleu_1': 0.724605241321865,
#    'Bleu_2': 0.5525687500346068,
#    'Bleu_3': 0.4061095115665815,
#    'Bleu_4': 0.28183048265253374,
#    'CIDEr': 0.24107499710103611,
#    'METEOR': 0.2289711571487315,
#    'ROUGE_L': 0.55142605527287747}),
#  ('model-20124',
#   {'Bleu_1': 0.752108929092092,
#    'Bleu_2': 0.5803815666325065,
#    'Bleu_3': 0.43159307744723907,
#    'Bleu_4': 0.31171693325768995,
#    'CIDEr': 0.36435426608250204,
#    'METEOR': 0.2532907990305215,
#    'ROUGE_L': 0.55760286283158955}),
#  ('model-5272',
#   {'Bleu_1': 0.7798297532994217,
#    'Bleu_2': 0.6260033318156948,
#    'Bleu_3': 0.48358730649903453,
#    'Bleu_4': 0.3635407390415018,
#    'CIDEr': 0.40749014863503807,
#    'METEOR': 0.2631893621669644,
#    'ROUGE_L': 0.58614086084834094}),
#  ('model-13416',
#   {'Bleu_1': 0.7649582051926987,
#    'Bleu_2': 0.6046034105628594,
#    'Bleu_3': 0.4620996686067891,
#    'Bleu_4': 0.3421677598546643,
#    'CIDEr': 0.38551380418712433,
#    'METEOR': 0.2597180794622389,
#    'ROUGE_L': 0.57241125686502203}),
#  ('model-9644',
#   {'Bleu_1': 0.771266204308888,
#    'Bleu_2': 0.6125609885421095,
#    'Bleu_3': 0.4683833280506975,
#    'Bleu_4': 0.3476119939310615,
#    'CIDEr': 0.40340516461755427,
#    'METEOR': 0.26314547028721824,
#    'ROUGE_L': 0.57857514162613854}),
#  ('model-11380',
#   {'Bleu_1': 0.7707054961082325,
#    'Bleu_2': 0.6073276052992533,
#    'Bleu_3': 0.4607797816637351,
#    'Bleu_4': 0.33933769190776547,
#    'CIDEr': 0.38991749177770968,
#    'METEOR': 0.26105606946435916,
#    'ROUGE_L': 0.57267038845975926}),
#  ('model-1200',
#   {'Bleu_1': 0.7468998517584884,
#    'Bleu_2': 0.5810500155484973,
#    'Bleu_3': 0.44070216470875073,
#    'Bleu_4': 0.3213886574363764,
#    'CIDEr': 0.31376446027802285,
#    'METEOR': 0.24644701884402448,
#    'ROUGE_L': 0.56834462180097556}),
#  ('model-3236',
#   {'Bleu_1': 0.7744167517806329,
#    'Bleu_2': 0.6193825091477887,
#    'Bleu_3': 0.48046016927369195,
#    'Bleu_4': 0.3577403468767428,
#    'CIDEr': 0.38914040044452602,
#    'METEOR': 0.260785137310902,
#    'ROUGE_L': 0.58869719255658604}),
#  ('model-15452',
#   {'Bleu_1': 0.7650400555125482,
#    'Bleu_2': 0.6036819179820311,
#    'Bleu_3': 0.4586604926389984,
#    'Bleu_4': 0.33744151097642466,
#    'CIDEr': 0.38790860089121038,
#    'METEOR': 0.25887988378934484,
#    'ROUGE_L': 0.56945671864926695}),
#  ('model-7008',
#   {'Bleu_1': 0.7677535833658505,
#    'Bleu_2': 0.6017822194360652,
#    'Bleu_3': 0.45601314523472697,
#    'Bleu_4': 0.336267560609823,
#    'CIDEr': 0.38342331826134513,
#    'METEOR': 0.2595377965536394,
#    'ROUGE_L': 0.56954091244158855}),
#  ('model-900',
#   {'Bleu_1': 0.7373447946733929,
#    'Bleu_2': 0.5687928399469279,
#    'Bleu_3': 0.42685454826309077,
#    'Bleu_4': 0.3059030342763212,
#    'CIDEr': 0.26945917257077512,
#    'METEOR': 0.23778306018874243,
#    'ROUGE_L': 0.56108342581731985}),
#  ('model-18924',
#   {'Bleu_1': 0.7602671787367989,
#    'Bleu_2': 0.5905506577784814,
#    'Bleu_3': 0.4430233135467166,
#    'Bleu_4': 0.3234508807621384,
#    'CIDEr': 0.37243696882119609,
#    'METEOR': 0.25859882180640853,
#    'ROUGE_L': 0.56186505388425334}),
#  ('model-7308',
#   {'Bleu_1': 0.7795633381912286,
#    'Bleu_2': 0.6205003724846323,
#    'Bleu_3': 0.47327827097335223,
#    'Bleu_4': 0.3465330690899732,
#    'CIDEr': 0.39528794242064547,
#    'METEOR': 0.2614360729284989,
#    'ROUGE_L': 0.58027799851448525}),
#  ('model-17788',
#   {'Bleu_1': 0.7572778338719248,
#    'Bleu_2': 0.5863401545351897,
#    'Bleu_3': 0.4390383650436989,
#    'Bleu_4': 0.3206796925623692,
#    'CIDEr': 0.37674442473777209,
#    'METEOR': 0.25700168935260154,
#    'ROUGE_L': 0.56246004258969839}),
#  ('model-11680',
#   {'Bleu_1': 0.7660786612007996,
#    'Bleu_2': 0.6030678090147279,
#    'Bleu_3': 0.45591851112294635,
#    'Bleu_4': 0.33649010975335447,
#    'CIDEr': 0.39276543751159126,
#    'METEOR': 0.2595641339287099,
#    'ROUGE_L': 0.57058730652661904}),
#  ('model-18088',
#   {'Bleu_1': 0.7603283261297766,
#    'Bleu_2': 0.590602095632715,
#    'Bleu_3': 0.44413153131088673,
#    'Bleu_4': 0.3235913601717598,
#    'CIDEr': 0.37231764319774402,
#    'METEOR': 0.25527537942101186,
#    'ROUGE_L': 0.56280906206921066}),
#  ('model-2636',
#   {'Bleu_1': 0.776776747698877,
#    'Bleu_2': 0.6224259736325523,
#    'Bleu_3': 0.4813431155773317,
#    'Bleu_4': 0.3579714603746146,
#    'CIDEr': 0.38544100849096724,
#    'METEOR': 0.2592507583041669,
#    'ROUGE_L': 0.58359954818963322}),
#  ('model-5872',
#   {'Bleu_1': 0.7797403440078235,
#    'Bleu_2': 0.6238188643352627,
#    'Bleu_3': 0.4794771716400061,
#    'Bleu_4': 0.35598802553881587,
#    'CIDEr': 0.40710598447527979,
#    'METEOR': 0.2643094133947532,
#    'ROUGE_L': 0.58318471503930014}),
#  ('model-19524',
#   {'Bleu_1': 0.7557558744112296,
#    'Bleu_2': 0.5904438454925341,
#    'Bleu_3': 0.44632011110727365,
#    'Bleu_4': 0.32695562109563336,
#    'CIDEr': 0.37175508331257451,
#    'METEOR': 0.2586094995295237,
#    'ROUGE_L': 0.56662694511744593}),
#  ('model-19824',
#   {'Bleu_1': 0.7599068389826659,
#    'Bleu_2': 0.5940937775112723,
#    'Bleu_3': 0.4474159882401391,
#    'Bleu_4': 0.3252447318199321,
#    'CIDEr': 0.37169474412225356,
#    'METEOR': 0.2563414432750198,
#    'ROUGE_L': 0.56424377259294656}),
#  ('model-8444',
#   {'Bleu_1': 0.7763873705934651,
#    'Bleu_2': 0.6137338126668775,
#    'Bleu_3': 0.46704039226299504,
#    'Bleu_4': 0.344505810382968,
#    'CIDEr': 0.38858760205105453,
#    'METEOR': 0.26064599594827614,
#    'ROUGE_L': 0.57579393217063668}),
#  ('model-12516',
#   {'Bleu_1': 0.7684544124090786,
#    'Bleu_2': 0.5997922948070656,
#    'Bleu_3': 0.45130526602001464,
#    'Bleu_4': 0.3283616642172344,
#    'CIDEr': 0.37369675477349956,
#    'METEOR': 0.25750806554279954,
#    'ROUGE_L': 0.56798163169077798}),
#  ('model-4372',
#   {'Bleu_1': 0.7786879279348097,
#    'Bleu_2': 0.6293662180856576,
#    'Bleu_3': 0.4899209162183454,
#    'Bleu_4': 0.3672948382616445,
#    'CIDEr': 0.39992505830898128,
#    'METEOR': 0.2631149803775965,
#    'ROUGE_L': 0.58762717954889054}),
#  ('model-16888',
#   {'Bleu_1': 0.7584778767648115,
#    'Bleu_2': 0.5917355183623577,
#    'Bleu_3': 0.4469860255291639,
#    'Bleu_4': 0.3273405314438715,
#    'CIDEr': 0.37564941000428709,
#    'METEOR': 0.25632046505471046,
#    'ROUGE_L': 0.56632977955323938}),
#  ('model-19224',
#   {'Bleu_1': 0.7583054686046868,
#    'Bleu_2': 0.5924534835883807,
#    'Bleu_3': 0.44751785358775714,
#    'Bleu_4': 0.3290066720005419,
#    'CIDEr': 0.38041018975792168,
#    'METEOR': 0.2567403364162194,
#    'ROUGE_L': 0.56769319392218631}),
#  ('model-9344',
#   {'Bleu_1': 0.7703356276418166,
#    'Bleu_2': 0.6083881734963953,
#    'Bleu_3': 0.46295110983000415,
#    'Bleu_4': 0.3416497993313901,
#    'CIDEr': 0.38954443994128141,
#    'METEOR': 0.26224368888431776,
#    'ROUGE_L': 0.57282402985712988}),
#  ('model-11080',
#   {'Bleu_1': 0.7716144742875481,
#    'Bleu_2': 0.610101755548538,
#    'Bleu_3': 0.4664183049077527,
#    'Bleu_4': 0.34573060018793567,
#    'CIDEr': 0.39253881765400822,
#    'METEOR': 0.2587742086576066,
#    'ROUGE_L': 0.57226879911900053}),
#  ('model-300',
#   {'Bleu_1': 0.7022949598872751,
#    'Bleu_2': 0.517784046685997,
#    'Bleu_3': 0.3718352328115167,
#    'Bleu_4': 0.24260499323931933,
#    'CIDEr': 0.16380208366585763,
#    'METEOR': 0.21568666150771768,
#    'ROUGE_L': 0.52814666474951244}),
#  ('model-2336',
#   {'Bleu_1': 0.7601383904251404,
#    'Bleu_2': 0.6037117705523777,
#    'Bleu_3': 0.4624568648837679,
#    'Bleu_4': 0.34093301000430126,
#    'CIDEr': 0.35579484813607809,
#    'METEOR': 0.2538563497193074,
#    'ROUGE_L': 0.57739748142338776}),
#  ('model-15152',
#   {'Bleu_1': 0.756105920693954,
#    'Bleu_2': 0.5897361092718856,
#    'Bleu_3': 0.4449331123220681,
#    'Bleu_4': 0.3270909857724654,
#    'CIDEr': 0.37695940153309043,
#    'METEOR': 0.25793275498618834,
#    'ROUGE_L': 0.5637822569386689}),
#  ('model-11980',
#   {'Bleu_1': 0.7736238032064217,
#    'Bleu_2': 0.6168684336326695,
#    'Bleu_3': 0.47528306259209196,
#    'Bleu_4': 0.35579860301722155,
#    'CIDEr': 0.40346488787745483,
#    'METEOR': 0.26442880990600287,
#    'ROUGE_L': 0.58019466543775522}),
#  ('model-15752',
#   {'Bleu_1': 0.7581599975362291,
#    'Bleu_2': 0.5894919571251813,
#    'Bleu_3': 0.4426938523110603,
#    'Bleu_4': 0.3218330985559934,
#    'CIDEr': 0.37508503136864785,
#    'METEOR': 0.2579510602370966,
#    'ROUGE_L': 0.56152910934460198}),
#  ('model-14016',
#   {'Bleu_1': 0.7582796255092666,
#    'Bleu_2': 0.5976318964049631,
#    'Bleu_3': 0.4547763806953738,
#    'Bleu_4': 0.33665133470901903,
#    'CIDEr': 0.3775272732051253,
#    'METEOR': 0.2568862100446346,
#    'ROUGE_L': 0.56933918721140286}),
#  ('model-6708',
#   {'Bleu_1': 0.7700036790824102,
#    'Bleu_2': 0.6052348190174791,
#    'Bleu_3': 0.4562610002592101,
#    'Bleu_4': 0.33239335095558037,
#    'CIDEr': 0.38480986600559031,
#    'METEOR': 0.26206758260774626,
#    'ROUGE_L': 0.57239649716899754}),
#  ('model-7908',
#   {'Bleu_1': 0.778768333524613,
#    'Bleu_2': 0.6229357035320051,
#    'Bleu_3': 0.47882447541335954,
#    'Bleu_4': 0.3555535648592916,
#    'CIDEr': 0.40099389978158628,
#    'METEOR': 0.26433011708205945,
#    'ROUGE_L': 0.58349043280422863}),
#  ('model-7608',
#   {'Bleu_1': 0.7761663877083914,
#    'Bleu_2': 0.6208122092210436,
#    'Bleu_3': 0.4788970130545418,
#    'Bleu_4': 0.358573601703613,
#    'CIDEr': 0.40360309353888674,
#    'METEOR': 0.26242647944276193,
#    'ROUGE_L': 0.58077498467466149}),
#  ('model-9944',
#   {'Bleu_1': 0.7707214170103406,
#    'Bleu_2': 0.6153239241910928,
#    'Bleu_3': 0.4736323548163931,
#    'Bleu_4': 0.35272074699142913,
#    'CIDEr': 0.39383070861335018,
#    'METEOR': 0.2624014608038259,
#    'ROUGE_L': 0.57824023425178017}),
#  ('model-1800',
#   {'Bleu_1': 0.7545650543144693,
#    'Bleu_2': 0.5979570447626316,
#    'Bleu_3': 0.45908734755449415,
#    'Bleu_4': 0.3400563964916923,
#    'CIDEr': 0.35185920430040402,
#    'METEOR': 0.2510281690617274,
#    'ROUGE_L': 0.5784509721328388}),
#  ('model-3836',
#   {'Bleu_1': 0.7740873610816468,
#    'Bleu_2': 0.6219901004364637,
#    'Bleu_3': 0.48253554025145934,
#    'Bleu_4': 0.36229689916942115,
#    'CIDEr': 0.39024546795543458,
#    'METEOR': 0.26196530783001665,
#    'ROUGE_L': 0.58429558571865547}),
#  ('model-10780',
#   {'Bleu_1': 0.7671441564514818,
#    'Bleu_2': 0.6070285088905999,
#    'Bleu_3': 0.4602262610661521,
#    'Bleu_4': 0.33733373153208723,
#    'CIDEr': 0.39200075797624218,
#    'METEOR': 0.25900609111808925,
#    'ROUGE_L': 0.57129895847042733}),
#  ('model-1500',
#   {'Bleu_1': 0.7510433722708627,
#    'Bleu_2': 0.5888609217477244,
#    'Bleu_3': 0.44908923578255194,
#    'Bleu_4': 0.3285259039113581,
#    'CIDEr': 0.34203034765505524,
#    'METEOR': 0.25180658115864984,
#    'ROUGE_L': 0.57568992435419442}),
#  ('model-14552',
#   {'Bleu_1': 0.760482399828857,
#    'Bleu_2': 0.5926222444178705,
#    'Bleu_3': 0.4461945963304571,
#    'Bleu_4': 0.3244721461761706,
#    'CIDEr': 0.37326754362608144,
#    'METEOR': 0.2551159588983404,
#    'ROUGE_L': 0.5618818010410449}),
#  ('model-17488',
#   {'Bleu_1': 0.7588117836588056,
#    'Bleu_2': 0.5962702881935678,
#    'Bleu_3': 0.45303277747859255,
#    'Bleu_4': 0.33590704789829123,
#    'CIDEr': 0.37795149759983426,
#    'METEOR': 0.2578247877549109,
#    'ROUGE_L': 0.56713101935197929}),
#  ('model-13116',
#   {'Bleu_1': 0.7676336542770865,
#    'Bleu_2': 0.6022239110252647,
#    'Bleu_3': 0.4538551623927866,
#    'Bleu_4': 0.33030285308158447,
#    'CIDEr': 0.37721899144061732,
#    'METEOR': 0.25921900455877367,
#    'ROUGE_L': 0.56898416395851004}),
#  ('model-17188',
#   {'Bleu_1': 0.7621370337108913,
#    'Bleu_2': 0.592060078554462,
#    'Bleu_3': 0.4446773445537006,
#    'Bleu_4': 0.3215633854275437,
#    'CIDEr': 0.37658596514455023,
#    'METEOR': 0.25733971128854566,
#    'ROUGE_L': 0.56357413386711996}),
#  ('model-14852',
#   {'Bleu_1': 0.7646728773290553,
#    'Bleu_2': 0.5938891055381509,
#    'Bleu_3': 0.4472596378947664,
#    'Bleu_4': 0.32714013920564283,
#    'CIDEr': 0.37737602656914132,
#    'METEOR': 0.26042452268282335,
#    'ROUGE_L': 0.56477126271249112}),
#  ('model-3536',
#   {'Bleu_1': 0.7740623109842479,
#    'Bleu_2': 0.6239092940829329,
#    'Bleu_3': 0.48433115899523216,
#    'Bleu_4': 0.3636226827315795,
#    'CIDEr': 0.39086931551347509,
#    'METEOR': 0.25863442778802737,
#    'ROUGE_L': 0.58516888262527611})]

# %%
c.sort(key=lambda x: int(x[0][6:]))

# %%
c
# Out:
# [('model-300',
#   {'Bleu_1': 0.7022949598872751,
#    'Bleu_2': 0.517784046685997,
#    'Bleu_3': 0.3718352328115167,
#    'Bleu_4': 0.24260499323931933,
#    'CIDEr': 0.16380208366585763,
#    'METEOR': 0.21568666150771768,
#    'ROUGE_L': 0.52814666474951244}),
#  ('model-600',
#   {'Bleu_1': 0.724605241321865,
#    'Bleu_2': 0.5525687500346068,
#    'Bleu_3': 0.4061095115665815,
#    'Bleu_4': 0.28183048265253374,
#    'CIDEr': 0.24107499710103611,
#    'METEOR': 0.2289711571487315,
#    'ROUGE_L': 0.55142605527287747}),
#  ('model-900',
#   {'Bleu_1': 0.7373447946733929,
#    'Bleu_2': 0.5687928399469279,
#    'Bleu_3': 0.42685454826309077,
#    'Bleu_4': 0.3059030342763212,
#    'CIDEr': 0.26945917257077512,
#    'METEOR': 0.23778306018874243,
#    'ROUGE_L': 0.56108342581731985}),
#  ('model-1200',
#   {'Bleu_1': 0.7468998517584884,
#    'Bleu_2': 0.5810500155484973,
#    'Bleu_3': 0.44070216470875073,
#    'Bleu_4': 0.3213886574363764,
#    'CIDEr': 0.31376446027802285,
#    'METEOR': 0.24644701884402448,
#    'ROUGE_L': 0.56834462180097556}),
#  ('model-1500',
#   {'Bleu_1': 0.7510433722708627,
#    'Bleu_2': 0.5888609217477244,
#    'Bleu_3': 0.44908923578255194,
#    'Bleu_4': 0.3285259039113581,
#    'CIDEr': 0.34203034765505524,
#    'METEOR': 0.25180658115864984,
#    'ROUGE_L': 0.57568992435419442}),
#  ('model-1800',
#   {'Bleu_1': 0.7545650543144693,
#    'Bleu_2': 0.5979570447626316,
#    'Bleu_3': 0.45908734755449415,
#    'Bleu_4': 0.3400563964916923,
#    'CIDEr': 0.35185920430040402,
#    'METEOR': 0.2510281690617274,
#    'ROUGE_L': 0.5784509721328388}),
#  ('model-2336',
#   {'Bleu_1': 0.7601383904251404,
#    'Bleu_2': 0.6037117705523777,
#    'Bleu_3': 0.4624568648837679,
#    'Bleu_4': 0.34093301000430126,
#    'CIDEr': 0.35579484813607809,
#    'METEOR': 0.2538563497193074,
#    'ROUGE_L': 0.57739748142338776}),
#  ('model-2636',
#   {'Bleu_1': 0.776776747698877,
#    'Bleu_2': 0.6224259736325523,
#    'Bleu_3': 0.4813431155773317,
#    'Bleu_4': 0.3579714603746146,
#    'CIDEr': 0.38544100849096724,
#    'METEOR': 0.2592507583041669,
#    'ROUGE_L': 0.58359954818963322}),
#  ('model-2936',
#   {'Bleu_1': 0.7700672179658002,
#    'Bleu_2': 0.6149940071476686,
#    'Bleu_3': 0.47565646215587715,
#    'Bleu_4': 0.3557744679067562,
#    'CIDEr': 0.37956650308675643,
#    'METEOR': 0.2563373740201271,
#    'ROUGE_L': 0.58426787497844501}),
#  ('model-3236',
#   {'Bleu_1': 0.7744167517806329,
#    'Bleu_2': 0.6193825091477887,
#    'Bleu_3': 0.48046016927369195,
#    'Bleu_4': 0.3577403468767428,
#    'CIDEr': 0.38914040044452602,
#    'METEOR': 0.260785137310902,
#    'ROUGE_L': 0.58869719255658604}),
#  ('model-3536',
#   {'Bleu_1': 0.7740623109842479,
#    'Bleu_2': 0.6239092940829329,
#    'Bleu_3': 0.48433115899523216,
#    'Bleu_4': 0.3636226827315795,
#    'CIDEr': 0.39086931551347509,
#    'METEOR': 0.25863442778802737,
#    'ROUGE_L': 0.58516888262527611}),
#  ('model-3836',
#   {'Bleu_1': 0.7740873610816468,
#    'Bleu_2': 0.6219901004364637,
#    'Bleu_3': 0.48253554025145934,
#    'Bleu_4': 0.36229689916942115,
#    'CIDEr': 0.39024546795543458,
#    'METEOR': 0.26196530783001665,
#    'ROUGE_L': 0.58429558571865547}),
#  ('model-4372',
#   {'Bleu_1': 0.7786879279348097,
#    'Bleu_2': 0.6293662180856576,
#    'Bleu_3': 0.4899209162183454,
#    'Bleu_4': 0.3672948382616445,
#    'CIDEr': 0.39992505830898128,
#    'METEOR': 0.2631149803775965,
#    'ROUGE_L': 0.58762717954889054}),
#  ('model-4672',
#   {'Bleu_1': 0.7705102847685613,
#    'Bleu_2': 0.6129827379323538,
#    'Bleu_3': 0.4707173365318577,
#    'Bleu_4': 0.34696339624212713,
#    'CIDEr': 0.38960583423542072,
#    'METEOR': 0.2573141443468951,
#    'ROUGE_L': 0.5760575387473339}),
#  ('model-4972',
#   {'Bleu_1': 0.779589121730603,
#    'Bleu_2': 0.6238867472210415,
#    'Bleu_3': 0.4785936660108123,
#    'Bleu_4': 0.35535147170722614,
#    'CIDEr': 0.40537140081271417,
#    'METEOR': 0.2632998138311796,
#    'ROUGE_L': 0.58300532431025143}),
#  ('model-5272',
#   {'Bleu_1': 0.7798297532994217,
#    'Bleu_2': 0.6260033318156948,
#    'Bleu_3': 0.48358730649903453,
#    'Bleu_4': 0.3635407390415018,
#    'CIDEr': 0.40749014863503807,
#    'METEOR': 0.2631893621669644,
#    'ROUGE_L': 0.58614086084834094}),
#  ('model-5572',
#   {'Bleu_1': 0.776807160398031,
#    'Bleu_2': 0.6178921039156946,
#    'Bleu_3': 0.4721289409561074,
#    'Bleu_4': 0.3502802086899458,
#    'CIDEr': 0.39814671812225005,
#    'METEOR': 0.2623074642829495,
#    'ROUGE_L': 0.58083935386965391}),
#  ('model-5872',
#   {'Bleu_1': 0.7797403440078235,
#    'Bleu_2': 0.6238188643352627,
#    'Bleu_3': 0.4794771716400061,
#    'Bleu_4': 0.35598802553881587,
#    'CIDEr': 0.40710598447527979,
#    'METEOR': 0.2643094133947532,
#    'ROUGE_L': 0.58318471503930014}),
#  ('model-6408',
#   {'Bleu_1': 0.7748908525751322,
#    'Bleu_2': 0.6194949713371428,
#    'Bleu_3': 0.4761867168325123,
#    'Bleu_4': 0.3541422957813222,
#    'CIDEr': 0.39364337012527068,
#    'METEOR': 0.2610190019115988,
#    'ROUGE_L': 0.58039308675592527}),
#  ('model-6708',
#   {'Bleu_1': 0.7700036790824102,
#    'Bleu_2': 0.6052348190174791,
#    'Bleu_3': 0.4562610002592101,
#    'Bleu_4': 0.33239335095558037,
#    'CIDEr': 0.38480986600559031,
#    'METEOR': 0.26206758260774626,
#    'ROUGE_L': 0.57239649716899754}),
#  ('model-7008',
#   {'Bleu_1': 0.7677535833658505,
#    'Bleu_2': 0.6017822194360652,
#    'Bleu_3': 0.45601314523472697,
#    'Bleu_4': 0.336267560609823,
#    'CIDEr': 0.38342331826134513,
#    'METEOR': 0.2595377965536394,
#    'ROUGE_L': 0.56954091244158855}),
#  ('model-7308',
#   {'Bleu_1': 0.7795633381912286,
#    'Bleu_2': 0.6205003724846323,
#    'Bleu_3': 0.47327827097335223,
#    'Bleu_4': 0.3465330690899732,
#    'CIDEr': 0.39528794242064547,
#    'METEOR': 0.2614360729284989,
#    'ROUGE_L': 0.58027799851448525}),
#  ('model-7608',
#   {'Bleu_1': 0.7761663877083914,
#    'Bleu_2': 0.6208122092210436,
#    'Bleu_3': 0.4788970130545418,
#    'Bleu_4': 0.358573601703613,
#    'CIDEr': 0.40360309353888674,
#    'METEOR': 0.26242647944276193,
#    'ROUGE_L': 0.58077498467466149}),
#  ('model-7908',
#   {'Bleu_1': 0.778768333524613,
#    'Bleu_2': 0.6229357035320051,
#    'Bleu_3': 0.47882447541335954,
#    'Bleu_4': 0.3555535648592916,
#    'CIDEr': 0.40099389978158628,
#    'METEOR': 0.26433011708205945,
#    'ROUGE_L': 0.58349043280422863}),
#  ('model-8444',
#   {'Bleu_1': 0.7763873705934651,
#    'Bleu_2': 0.6137338126668775,
#    'Bleu_3': 0.46704039226299504,
#    'Bleu_4': 0.344505810382968,
#    'CIDEr': 0.38858760205105453,
#    'METEOR': 0.26064599594827614,
#    'ROUGE_L': 0.57579393217063668}),
#  ('model-8744',
#   {'Bleu_1': 0.7727656955309871,
#    'Bleu_2': 0.6138386514764923,
#    'Bleu_3': 0.4685540607152158,
#    'Bleu_4': 0.34397928456915855,
#    'CIDEr': 0.39441689561535598,
#    'METEOR': 0.2597721410117236,
#    'ROUGE_L': 0.57490994451312827}),
#  ('model-9044',
#   {'Bleu_1': 0.773583009044845,
#    'Bleu_2': 0.606476588296607,
#    'Bleu_3': 0.45833960541263,
#    'Bleu_4': 0.3345407243301598,
#    'CIDEr': 0.39354468702456996,
#    'METEOR': 0.2633545680936823,
#    'ROUGE_L': 0.57281490858146022}),
#  ('model-9344',
#   {'Bleu_1': 0.7703356276418166,
#    'Bleu_2': 0.6083881734963953,
#    'Bleu_3': 0.46295110983000415,
#    'Bleu_4': 0.3416497993313901,
#    'CIDEr': 0.38954443994128141,
#    'METEOR': 0.26224368888431776,
#    'ROUGE_L': 0.57282402985712988}),
#  ('model-9644',
#   {'Bleu_1': 0.771266204308888,
#    'Bleu_2': 0.6125609885421095,
#    'Bleu_3': 0.4683833280506975,
#    'Bleu_4': 0.3476119939310615,
#    'CIDEr': 0.40340516461755427,
#    'METEOR': 0.26314547028721824,
#    'ROUGE_L': 0.57857514162613854}),
#  ('model-9944',
#   {'Bleu_1': 0.7707214170103406,
#    'Bleu_2': 0.6153239241910928,
#    'Bleu_3': 0.4736323548163931,
#    'Bleu_4': 0.35272074699142913,
#    'CIDEr': 0.39383070861335018,
#    'METEOR': 0.2624014608038259,
#    'ROUGE_L': 0.57824023425178017}),
#  ('model-10480',
#   {'Bleu_1': 0.7706949127221532,
#    'Bleu_2': 0.6045242287618017,
#    'Bleu_3': 0.4562077672626666,
#    'Bleu_4': 0.3325241314728971,
#    'CIDEr': 0.38329952112853244,
#    'METEOR': 0.2618892772050306,
#    'ROUGE_L': 0.57023677243255622}),
#  ('model-10780',
#   {'Bleu_1': 0.7671441564514818,
#    'Bleu_2': 0.6070285088905999,
#    'Bleu_3': 0.4602262610661521,
#    'Bleu_4': 0.33733373153208723,
#    'CIDEr': 0.39200075797624218,
#    'METEOR': 0.25900609111808925,
#    'ROUGE_L': 0.57129895847042733}),
#  ('model-11080',
#   {'Bleu_1': 0.7716144742875481,
#    'Bleu_2': 0.610101755548538,
#    'Bleu_3': 0.4664183049077527,
#    'Bleu_4': 0.34573060018793567,
#    'CIDEr': 0.39253881765400822,
#    'METEOR': 0.2587742086576066,
#    'ROUGE_L': 0.57226879911900053}),
#  ('model-11380',
#   {'Bleu_1': 0.7707054961082325,
#    'Bleu_2': 0.6073276052992533,
#    'Bleu_3': 0.4607797816637351,
#    'Bleu_4': 0.33933769190776547,
#    'CIDEr': 0.38991749177770968,
#    'METEOR': 0.26105606946435916,
#    'ROUGE_L': 0.57267038845975926}),
#  ('model-11680',
#   {'Bleu_1': 0.7660786612007996,
#    'Bleu_2': 0.6030678090147279,
#    'Bleu_3': 0.45591851112294635,
#    'Bleu_4': 0.33649010975335447,
#    'CIDEr': 0.39276543751159126,
#    'METEOR': 0.2595641339287099,
#    'ROUGE_L': 0.57058730652661904}),
#  ('model-11980',
#   {'Bleu_1': 0.7736238032064217,
#    'Bleu_2': 0.6168684336326695,
#    'Bleu_3': 0.47528306259209196,
#    'Bleu_4': 0.35579860301722155,
#    'CIDEr': 0.40346488787745483,
#    'METEOR': 0.26442880990600287,
#    'ROUGE_L': 0.58019466543775522}),
#  ('model-12516',
#   {'Bleu_1': 0.7684544124090786,
#    'Bleu_2': 0.5997922948070656,
#    'Bleu_3': 0.45130526602001464,
#    'Bleu_4': 0.3283616642172344,
#    'CIDEr': 0.37369675477349956,
#    'METEOR': 0.25750806554279954,
#    'ROUGE_L': 0.56798163169077798}),
#  ('model-12816',
#   {'Bleu_1': 0.7695285219495414,
#    'Bleu_2': 0.6092477193764696,
#    'Bleu_3': 0.46584844692796107,
#    'Bleu_4': 0.3443591273362451,
#    'CIDEr': 0.39198254460880055,
#    'METEOR': 0.2600121545229725,
#    'ROUGE_L': 0.57527835656638115}),
#  ('model-13116',
#   {'Bleu_1': 0.7676336542770865,
#    'Bleu_2': 0.6022239110252647,
#    'Bleu_3': 0.4538551623927866,
#    'Bleu_4': 0.33030285308158447,
#    'CIDEr': 0.37721899144061732,
#    'METEOR': 0.25921900455877367,
#    'ROUGE_L': 0.56898416395851004}),
#  ('model-13416',
#   {'Bleu_1': 0.7649582051926987,
#    'Bleu_2': 0.6046034105628594,
#    'Bleu_3': 0.4620996686067891,
#    'Bleu_4': 0.3421677598546643,
#    'CIDEr': 0.38551380418712433,
#    'METEOR': 0.2597180794622389,
#    'ROUGE_L': 0.57241125686502203}),
#  ('model-13716',
#   {'Bleu_1': 0.7702934658355158,
#    'Bleu_2': 0.6081135910036822,
#    'Bleu_3': 0.46268429698076247,
#    'Bleu_4': 0.341065107948712,
#    'CIDEr': 0.39180356998518023,
#    'METEOR': 0.2630280680511232,
#    'ROUGE_L': 0.57304028092872317}),
#  ('model-14016',
#   {'Bleu_1': 0.7582796255092666,
#    'Bleu_2': 0.5976318964049631,
#    'Bleu_3': 0.4547763806953738,
#    'Bleu_4': 0.33665133470901903,
#    'CIDEr': 0.3775272732051253,
#    'METEOR': 0.2568862100446346,
#    'ROUGE_L': 0.56933918721140286}),
#  ('model-14552',
#   {'Bleu_1': 0.760482399828857,
#    'Bleu_2': 0.5926222444178705,
#    'Bleu_3': 0.4461945963304571,
#    'Bleu_4': 0.3244721461761706,
#    'CIDEr': 0.37326754362608144,
#    'METEOR': 0.2551159588983404,
#    'ROUGE_L': 0.5618818010410449}),
#  ('model-14852',
#   {'Bleu_1': 0.7646728773290553,
#    'Bleu_2': 0.5938891055381509,
#    'Bleu_3': 0.4472596378947664,
#    'Bleu_4': 0.32714013920564283,
#    'CIDEr': 0.37737602656914132,
#    'METEOR': 0.26042452268282335,
#    'ROUGE_L': 0.56477126271249112}),
#  ('model-15152',
#   {'Bleu_1': 0.756105920693954,
#    'Bleu_2': 0.5897361092718856,
#    'Bleu_3': 0.4449331123220681,
#    'Bleu_4': 0.3270909857724654,
#    'CIDEr': 0.37695940153309043,
#    'METEOR': 0.25793275498618834,
#    'ROUGE_L': 0.5637822569386689}),
#  ('model-15452',
#   {'Bleu_1': 0.7650400555125482,
#    'Bleu_2': 0.6036819179820311,
#    'Bleu_3': 0.4586604926389984,
#    'Bleu_4': 0.33744151097642466,
#    'CIDEr': 0.38790860089121038,
#    'METEOR': 0.25887988378934484,
#    'ROUGE_L': 0.56945671864926695}),
#  ('model-15752',
#   {'Bleu_1': 0.7581599975362291,
#    'Bleu_2': 0.5894919571251813,
#    'Bleu_3': 0.4426938523110603,
#    'Bleu_4': 0.3218330985559934,
#    'CIDEr': 0.37508503136864785,
#    'METEOR': 0.2579510602370966,
#    'ROUGE_L': 0.56152910934460198}),
#  ('model-16052',
#   {'Bleu_1': 0.759605776517704,
#    'Bleu_2': 0.5982799861552048,
#    'Bleu_3': 0.45468495158250594,
#    'Bleu_4': 0.33298947160677017,
#    'CIDEr': 0.36782288811148217,
#    'METEOR': 0.2569874055651692,
#    'ROUGE_L': 0.56667069495692823}),
#  ('model-16588',
#   {'Bleu_1': 0.7539916463349127,
#    'Bleu_2': 0.5809424930059556,
#    'Bleu_3': 0.4325164172176445,
#    'Bleu_4': 0.3104851885905382,
#    'CIDEr': 0.37006342235891909,
#    'METEOR': 0.2568352010296076,
#    'ROUGE_L': 0.55847965434897517}),
#  ('model-16888',
#   {'Bleu_1': 0.7584778767648115,
#    'Bleu_2': 0.5917355183623577,
#    'Bleu_3': 0.4469860255291639,
#    'Bleu_4': 0.3273405314438715,
#    'CIDEr': 0.37564941000428709,
#    'METEOR': 0.25632046505471046,
#    'ROUGE_L': 0.56632977955323938}),
#  ('model-17188',
#   {'Bleu_1': 0.7621370337108913,
#    'Bleu_2': 0.592060078554462,
#    'Bleu_3': 0.4446773445537006,
#    'Bleu_4': 0.3215633854275437,
#    'CIDEr': 0.37658596514455023,
#    'METEOR': 0.25733971128854566,
#    'ROUGE_L': 0.56357413386711996}),
#  ('model-17488',
#   {'Bleu_1': 0.7588117836588056,
#    'Bleu_2': 0.5962702881935678,
#    'Bleu_3': 0.45303277747859255,
#    'Bleu_4': 0.33590704789829123,
#    'CIDEr': 0.37795149759983426,
#    'METEOR': 0.2578247877549109,
#    'ROUGE_L': 0.56713101935197929}),
#  ('model-17788',
#   {'Bleu_1': 0.7572778338719248,
#    'Bleu_2': 0.5863401545351897,
#    'Bleu_3': 0.4390383650436989,
#    'Bleu_4': 0.3206796925623692,
#    'CIDEr': 0.37674442473777209,
#    'METEOR': 0.25700168935260154,
#    'ROUGE_L': 0.56246004258969839}),
#  ('model-18088',
#   {'Bleu_1': 0.7603283261297766,
#    'Bleu_2': 0.590602095632715,
#    'Bleu_3': 0.44413153131088673,
#    'Bleu_4': 0.3235913601717598,
#    'CIDEr': 0.37231764319774402,
#    'METEOR': 0.25527537942101186,
#    'ROUGE_L': 0.56280906206921066}),
#  ('model-18624',
#   {'Bleu_1': 0.7561194348532949,
#    'Bleu_2': 0.5888118446573547,
#    'Bleu_3': 0.44322522308150186,
#    'Bleu_4': 0.32237237650607564,
#    'CIDEr': 0.36806319917805635,
#    'METEOR': 0.25445004941019483,
#    'ROUGE_L': 0.56016867142417293}),
#  ('model-18924',
#   {'Bleu_1': 0.7602671787367989,
#    'Bleu_2': 0.5905506577784814,
#    'Bleu_3': 0.4430233135467166,
#    'Bleu_4': 0.3234508807621384,
#    'CIDEr': 0.37243696882119609,
#    'METEOR': 0.25859882180640853,
#    'ROUGE_L': 0.56186505388425334}),
#  ('model-19224',
#   {'Bleu_1': 0.7583054686046868,
#    'Bleu_2': 0.5924534835883807,
#    'Bleu_3': 0.44751785358775714,
#    'Bleu_4': 0.3290066720005419,
#    'CIDEr': 0.38041018975792168,
#    'METEOR': 0.2567403364162194,
#    'ROUGE_L': 0.56769319392218631}),
#  ('model-19524',
#   {'Bleu_1': 0.7557558744112296,
#    'Bleu_2': 0.5904438454925341,
#    'Bleu_3': 0.44632011110727365,
#    'Bleu_4': 0.32695562109563336,
#    'CIDEr': 0.37175508331257451,
#    'METEOR': 0.2586094995295237,
#    'ROUGE_L': 0.56662694511744593}),
#  ('model-19824',
#   {'Bleu_1': 0.7599068389826659,
#    'Bleu_2': 0.5940937775112723,
#    'Bleu_3': 0.4474159882401391,
#    'Bleu_4': 0.3252447318199321,
#    'CIDEr': 0.37169474412225356,
#    'METEOR': 0.2563414432750198,
#    'ROUGE_L': 0.56424377259294656}),
#  ('model-20124',
#   {'Bleu_1': 0.752108929092092,
#    'Bleu_2': 0.5803815666325065,
#    'Bleu_3': 0.43159307744723907,
#    'Bleu_4': 0.31171693325768995,
#    'CIDEr': 0.36435426608250204,
#    'METEOR': 0.2532907990305215,
#    'ROUGE_L': 0.55760286283158955}),
#  ('model-20360',
#   {'Bleu_1': 0.7535207939836672,
#    'Bleu_2': 0.589583546959259,
#    'Bleu_3': 0.44581478751570874,
#    'Bleu_4': 0.3258163839519824,
#    'CIDEr': 0.37132785561604098,
#    'METEOR': 0.2536114541233807,
#    'ROUGE_L': 0.56251681573022083})]

# %%
result_files.sort(key=lambda x: int(x[6:-15]) )

# %%
result_files
# Out:
# ['model-300_generated.json',
#  'model-600_generated.json',
#  'model-900_generated.json',
#  'model-1200_generated.json',
#  'model-1500_generated.json',
#  'model-1800_generated.json',
#  'model-2336_generated.json',
#  'model-2636_generated.json',
#  'model-2936_generated.json',
#  'model-3236_generated.json',
#  'model-3536_generated.json',
#  'model-3836_generated.json',
#  'model-4372_generated.json',
#  'model-4672_generated.json',
#  'model-4972_generated.json',
#  'model-5272_generated.json',
#  'model-5572_generated.json',
#  'model-5872_generated.json',
#  'model-6408_generated.json',
#  'model-6708_generated.json',
#  'model-7008_generated.json',
#  'model-7308_generated.json',
#  'model-7608_generated.json',
#  'model-7908_generated.json',
#  'model-8444_generated.json',
#  'model-8744_generated.json',
#  'model-9044_generated.json',
#  'model-9344_generated.json',
#  'model-9644_generated.json',
#  'model-9944_generated.json',
#  'model-10480_generated.json',
#  'model-10780_generated.json',
#  'model-11080_generated.json',
#  'model-11380_generated.json',
#  'model-11680_generated.json',
#  'model-11980_generated.json',
#  'model-12516_generated.json',
#  'model-12816_generated.json',
#  'model-13116_generated.json',
#  'model-13416_generated.json',
#  'model-13716_generated.json',
#  'model-14016_generated.json',
#  'model-14552_generated.json',
#  'model-14852_generated.json',
#  'model-15152_generated.json',
#  'model-15452_generated.json',
#  'model-15752_generated.json',
#  'model-16052_generated.json',
#  'model-16588_generated.json',
#  'model-16888_generated.json',
#  'model-17188_generated.json',
#  'model-17488_generated.json',
#  'model-17788_generated.json',
#  'model-18088_generated.json',
#  'model-18624_generated.json',
#  'model-18924_generated.json',
#  'model-19224_generated.json',
#  'model-19524_generated.json',
#  'model-19824_generated.json',
#  'model-20124_generated.json',
#  'model-20360_generated.json']

# %%
data_config = configuration.DataConfig().config
result_files = [i for i in os.listdir(data_config["result_dir"]) if "_generated.json" in i]
models = [i[:-15] for i in result_files]
scores = []
for result in result_files:
    res = get_score("reference.json",result,data_config)
    scores.append(res.eval)
# Out:
# loading annotations into memory...
# 0:00:00.632935
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 24577, 'guess': [24256, 21266, 18276, 15286], 'testlen': 24256, 'correct': [19014, 10246, 4848, 2015]}
# ratio: 0.986939008016
# Bleu_1: 0.774
# Bleu_2: 0.606
# Bleu_3: 0.458
# Bleu_4: 0.335
# computing METEOR score...
# METEOR: 0.263
# computing Rouge score...
# ROUGE_L: 0.573
# computing CIDEr score...
# CIDEr: 0.394
# loading annotations into memory...
# 0:00:00.373319
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 24249, 'guess': [23863, 20873, 17883, 14893], 'testlen': 23863, 'correct': [18691, 10059, 4722, 1949]}
# ratio: 0.984081817807
# Bleu_1: 0.771
# Bleu_2: 0.605
# Bleu_3: 0.456
# Bleu_4: 0.333
# computing METEOR score...
# METEOR: 0.262
# computing Rouge score...
# ROUGE_L: 0.570
# computing CIDEr score...
# CIDEr: 0.383
# loading annotations into memory...
# 0:00:00.383083
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23240, 'guess': [22523, 19533, 16543, 13553], 'testlen': 22523, 'correct': [17662, 9502, 4485, 1830]}
# ratio: 0.969148020654
# Bleu_1: 0.760
# Bleu_2: 0.598
# Bleu_3: 0.455
# Bleu_4: 0.333
# computing METEOR score...
# METEOR: 0.257
# computing Rouge score...
# ROUGE_L: 0.567
# computing CIDEr score...
# CIDEr: 0.368
# loading annotations into memory...
# 0:00:00.376446
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 22679, 'guess': [21853, 18863, 15873, 12883], 'testlen': 21853, 'correct': [17586, 9702, 4638, 1949]}
# ratio: 0.963578641034
# Bleu_1: 0.775
# Bleu_2: 0.619
# Bleu_3: 0.476
# Bleu_4: 0.354
# computing METEOR score...
# METEOR: 0.261
# computing Rouge score...
# ROUGE_L: 0.580
# computing CIDEr score...
# CIDEr: 0.394
# loading annotations into memory...
# 0:00:00.387625
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23034, 'guess': [22219, 19229, 16239, 13249], 'testlen': 22219, 'correct': [17368, 9202, 4294, 1748]}
# ratio: 0.964617521924
# Bleu_1: 0.754
# Bleu_2: 0.590
# Bleu_3: 0.446
# Bleu_4: 0.326
# computing METEOR score...
# METEOR: 0.254
# computing Rouge score...
# ROUGE_L: 0.563
# computing CIDEr score...
# CIDEr: 0.371
# loading annotations into memory...
# 0:00:00.377014
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23046, 'guess': [22389, 19399, 16409, 13419], 'testlen': 22389, 'correct': [17974, 9974, 4759, 2010]}
# ratio: 0.971491799011
# Bleu_1: 0.780
# Bleu_2: 0.624
# Bleu_3: 0.479
# Bleu_4: 0.355
# computing METEOR score...
# METEOR: 0.263
# computing Rouge score...
# ROUGE_L: 0.583
# computing CIDEr score...
# CIDEr: 0.405
# loading annotations into memory...
# 0:00:00.374147
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.11s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23093, 'guess': [22409, 19419, 16429, 13439], 'testlen': 22409, 'correct': [17947, 9840, 4669, 1982]}
# ratio: 0.970380634824
# Bleu_1: 0.777
# Bleu_2: 0.618
# Bleu_3: 0.472
# Bleu_4: 0.350
# computing METEOR score...
# METEOR: 0.262
# computing Rouge score...
# ROUGE_L: 0.581
# computing CIDEr score...
# CIDEr: 0.398
# loading annotations into memory...
# 0:00:00.380451
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 22740, 'guess': [21921, 18931, 15941, 12951], 'testlen': 21921, 'correct': [17511, 9479, 4507, 1870]}
# ratio: 0.963984168865
# Bleu_1: 0.770
# Bleu_2: 0.609
# Bleu_3: 0.466
# Bleu_4: 0.344
# computing METEOR score...
# METEOR: 0.260
# computing Rouge score...
# ROUGE_L: 0.575
# computing CIDEr score...
# CIDEr: 0.392
# loading annotations into memory...
# 0:00:00.370119
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 21512, 'guess': [20323, 17333, 14343, 11353], 'testlen': 20323, 'correct': [16593, 9026, 4327, 1792]}
# ratio: 0.944728523615
# Bleu_1: 0.770
# Bleu_2: 0.615
# Bleu_3: 0.476
# Bleu_4: 0.356
# computing METEOR score...
# METEOR: 0.256
# computing Rouge score...
# ROUGE_L: 0.584
# computing CIDEr score...
# CIDEr: 0.380
# loading annotations into memory...
# 0:00:00.376655
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 22202, 'guess': [21294, 18304, 15314, 12324], 'testlen': 21294, 'correct': [17122, 9315, 4436, 1787]}
# ratio: 0.959102783533
# Bleu_1: 0.771
# Bleu_2: 0.613
# Bleu_3: 0.471
# Bleu_4: 0.347
# computing METEOR score...
# METEOR: 0.257
# computing Rouge score...
# ROUGE_L: 0.576
# computing CIDEr score...
# CIDEr: 0.390
# loading annotations into memory...
# 0:00:00.370318
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23489, 'guess': [22819, 19829, 16839, 13849], 'testlen': 22819, 'correct': [17768, 9363, 4355, 1769]}
# ratio: 0.971476010047
# Bleu_1: 0.756
# Bleu_2: 0.589
# Bleu_3: 0.443
# Bleu_4: 0.322
# computing METEOR score...
# METEOR: 0.254
# computing Rouge score...
# ROUGE_L: 0.560
# computing CIDEr score...
# CIDEr: 0.368
# loading annotations into memory...
# 0:00:00.367518
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 22998, 'guess': [22284, 19294, 16304, 13314], 'testlen': 22284, 'correct': [17781, 9714, 4596, 1871]}
# ratio: 0.968953822071
# Bleu_1: 0.773
# Bleu_2: 0.614
# Bleu_3: 0.469
# Bleu_4: 0.344
# computing METEOR score...
# METEOR: 0.260
# computing Rouge score...
# ROUGE_L: 0.575
# computing CIDEr score...
# CIDEr: 0.394
# loading annotations into memory...
# 0:00:00.363476
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 25118, 'guess': [24833, 21843, 18853, 15863], 'testlen': 24833, 'correct': [18940, 9890, 4572, 1843]}
# ratio: 0.988653555219
# Bleu_1: 0.754
# Bleu_2: 0.581
# Bleu_3: 0.433
# Bleu_4: 0.310
# computing METEOR score...
# METEOR: 0.257
# computing Rouge score...
# ROUGE_L: 0.558
# computing CIDEr score...
# CIDEr: 0.370
# loading annotations into memory...
# 0:00:00.365243
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23504, 'guess': [22959, 19969, 16979, 13989], 'testlen': 22959, 'correct': [18110, 9817, 4657, 1957]}
# ratio: 0.976812457454
# Bleu_1: 0.770
# Bleu_2: 0.608
# Bleu_3: 0.463
# Bleu_4: 0.341
# computing METEOR score...
# METEOR: 0.263
# computing Rouge score...
# ROUGE_L: 0.573
# computing CIDEr score...
# CIDEr: 0.392
# loading annotations into memory...
# 0:00:00.377724
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 21037, 'guess': [19684, 16694, 13704, 10714], 'testlen': 19684, 'correct': [15278, 7535, 3220, 1081]}
# ratio: 0.935684745924
# Bleu_1: 0.725
# Bleu_2: 0.553
# Bleu_3: 0.406
# Bleu_4: 0.282
# computing METEOR score...
# METEOR: 0.229
# computing Rouge score...
# ROUGE_L: 0.551
# computing CIDEr score...
# CIDEr: 0.241
# loading annotations into memory...
# 0:00:00.364457
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 24497, 'guess': [24091, 21101, 18111, 15121], 'testlen': 24091, 'correct': [18427, 9611, 4396, 1806]}
# ratio: 0.983426542026
# Bleu_1: 0.752
# Bleu_2: 0.580
# Bleu_3: 0.432
# Bleu_4: 0.312
# computing METEOR score...
# METEOR: 0.253
# computing Rouge score...
# ROUGE_L: 0.558
# computing CIDEr score...
# CIDEr: 0.364
# loading annotations into memory...
# 0:00:00.365253
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 22351, 'guess': [21478, 18488, 15498, 12508], 'testlen': 21478, 'correct': [17444, 9676, 4658, 2012]}
# ratio: 0.960941344906
# Bleu_1: 0.780
# Bleu_2: 0.626
# Bleu_3: 0.484
# Bleu_4: 0.364
# computing METEOR score...
# METEOR: 0.263
# computing Rouge score...
# ROUGE_L: 0.586
# computing CIDEr score...
# CIDEr: 0.407
# loading annotations into memory...
# 0:00:00.371345
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 22793, 'guess': [22027, 19037, 16047, 13057], 'testlen': 22027, 'correct': [17446, 9419, 4485, 1878]}
# ratio: 0.966393190892
# Bleu_1: 0.765
# Bleu_2: 0.605
# Bleu_3: 0.462
# Bleu_4: 0.342
# computing METEOR score...
# METEOR: 0.260
# computing Rouge score...
# ROUGE_L: 0.572
# computing CIDEr score...
# CIDEr: 0.386
# loading annotations into memory...
# 0:00:00.361254
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23085, 'guess': [22354, 19364, 16374, 13384], 'testlen': 22354, 'correct': [17814, 9734, 4633, 1965]}
# ratio: 0.968334416288
# Bleu_1: 0.771
# Bleu_2: 0.613
# Bleu_3: 0.468
# Bleu_4: 0.348
# computing METEOR score...
# METEOR: 0.263
# computing Rouge score...
# ROUGE_L: 0.579
# computing CIDEr score...
# CIDEr: 0.403
# loading annotations into memory...
# 0:00:00.356101
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23455, 'guess': [22856, 19866, 16876, 13886], 'testlen': 22856, 'correct': [18083, 9760, 4595, 1932]}
# ratio: 0.974461735238
# Bleu_1: 0.771
# Bleu_2: 0.607
# Bleu_3: 0.461
# Bleu_4: 0.339
# computing METEOR score...
# METEOR: 0.261
# computing Rouge score...
# ROUGE_L: 0.573
# computing CIDEr score...
# CIDEr: 0.390
# loading annotations into memory...
# 0:00:00.364248
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 21657, 'guess': [20488, 17498, 14508, 11518], 'testlen': 20488, 'correct': [16201, 8374, 3894, 1520]}
# ratio: 0.946022071386
# Bleu_1: 0.747
# Bleu_2: 0.581
# Bleu_3: 0.441
# Bleu_4: 0.321
# computing METEOR score...
# METEOR: 0.246
# computing Rouge score...
# ROUGE_L: 0.568
# computing CIDEr score...
# CIDEr: 0.314
# loading annotations into memory...
# 0:00:00.356024
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 21931, 'guess': [20919, 17929, 14939, 11949], 'testlen': 20919, 'correct': [17003, 9322, 4533, 1852]}
# ratio: 0.953855273357
# Bleu_1: 0.774
# Bleu_2: 0.619
# Bleu_3: 0.480
# Bleu_4: 0.358
# computing METEOR score...
# METEOR: 0.261
# computing Rouge score...
# ROUGE_L: 0.589
# computing CIDEr score...
# CIDEr: 0.389
# loading annotations into memory...
# 0:00:00.351917
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23446, 'guess': [22765, 19775, 16785, 13795], 'testlen': 22765, 'correct': [17945, 9706, 4579, 1910]}
# ratio: 0.970954533822
# Bleu_1: 0.765
# Bleu_2: 0.604
# Bleu_3: 0.459
# Bleu_4: 0.337
# computing METEOR score...
# METEOR: 0.259
# computing Rouge score...
# ROUGE_L: 0.569
# computing CIDEr score...
# CIDEr: 0.388
# loading annotations into memory...
# 0:00:00.354014
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23629, 'guess': [22996, 20006, 17016, 14026], 'testlen': 22996, 'correct': [18148, 9700, 4580, 1944]}
# ratio: 0.973210884929
# Bleu_1: 0.768
# Bleu_2: 0.602
# Bleu_3: 0.456
# Bleu_4: 0.336
# computing METEOR score...
# METEOR: 0.260
# computing Rouge score...
# ROUGE_L: 0.570
# computing CIDEr score...
# CIDEr: 0.383
# loading annotations into memory...
# 0:00:00.351237
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 21935, 'guess': [20871, 17881, 14891, 11901], 'testlen': 20871, 'correct': [16194, 8256, 3767, 1410]}
# ratio: 0.951493047641
# Bleu_1: 0.737
# Bleu_2: 0.569
# Bleu_3: 0.427
# Bleu_4: 0.306
# computing METEOR score...
# METEOR: 0.238
# computing Rouge score...
# ROUGE_L: 0.561
# computing CIDEr score...
# CIDEr: 0.269
# loading annotations into memory...
# 0:00:00.351736
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 24466, 'guess': [24085, 21095, 18105, 15115], 'testlen': 24085, 'correct': [18603, 9831, 4586, 1933]}
# ratio: 0.984427368593
# Bleu_1: 0.760
# Bleu_2: 0.591
# Bleu_3: 0.443
# Bleu_4: 0.323
# computing METEOR score...
# METEOR: 0.259
# computing Rouge score...
# ROUGE_L: 0.562
# computing CIDEr score...
# CIDEr: 0.372
# loading annotations into memory...
# 0:00:00.346226
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23061, 'guess': [22408, 19418, 16428, 13438], 'testlen': 22408, 'correct': [17985, 9874, 4657, 1882]}
# ratio: 0.971683795152
# Bleu_1: 0.780
# Bleu_2: 0.621
# Bleu_3: 0.473
# Bleu_4: 0.347
# computing METEOR score...
# METEOR: 0.261
# computing Rouge score...
# ROUGE_L: 0.580
# computing CIDEr score...
# CIDEr: 0.395
# loading annotations into memory...
# 0:00:00.346129
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 24191, 'guess': [23781, 20791, 17801, 14811], 'testlen': 23781, 'correct': [18322, 9603, 4458, 1883]}
# ratio: 0.983051548096
# Bleu_1: 0.757
# Bleu_2: 0.586
# Bleu_3: 0.439
# Bleu_4: 0.321
# computing METEOR score...
# METEOR: 0.257
# computing Rouge score...
# ROUGE_L: 0.562
# computing CIDEr score...
# CIDEr: 0.377
# loading annotations into memory...
# 0:00:00.344787
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23224, 'guess': [22478, 19488, 16498, 13508], 'testlen': 22478, 'correct': [17801, 9564, 4444, 1889]}
# ratio: 0.967878057182
# Bleu_1: 0.766
# Bleu_2: 0.603
# Bleu_3: 0.456
# Bleu_4: 0.336
# computing METEOR score...
# METEOR: 0.260
# computing Rouge score...
# ROUGE_L: 0.571
# computing CIDEr score...
# CIDEr: 0.393
# loading annotations into memory...
# 0:00:00.342990
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23686, 'guess': [23144, 20154, 17164, 14174], 'testlen': 23144, 'correct': [18014, 9465, 4413, 1816]}
# ratio: 0.977117284472
# Bleu_1: 0.760
# Bleu_2: 0.591
# Bleu_3: 0.444
# Bleu_4: 0.324
# computing METEOR score...
# METEOR: 0.255
# computing Rouge score...
# ROUGE_L: 0.563
# computing CIDEr score...
# CIDEr: 0.372
# loading annotations into memory...
# 0:00:00.346450
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 21996, 'guess': [21043, 18053, 15063, 12073], 'testlen': 21043, 'correct': [17103, 9421, 4537, 1860]}
# ratio: 0.956673940716
# Bleu_1: 0.777
# Bleu_2: 0.622
# Bleu_3: 0.481
# Bleu_4: 0.358
# computing METEOR score...
# METEOR: 0.259
# computing Rouge score...
# ROUGE_L: 0.584
# computing CIDEr score...
# CIDEr: 0.385
# loading annotations into memory...
# 0:00:00.381907
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 22837, 'guess': [22086, 19096, 16106, 13116], 'testlen': 22086, 'correct': [17817, 9860, 4720, 1977]}
# ratio: 0.967114769891
# Bleu_1: 0.780
# Bleu_2: 0.624
# Bleu_3: 0.479
# Bleu_4: 0.356
# computing METEOR score...
# METEOR: 0.264
# computing Rouge score...
# ROUGE_L: 0.583
# computing CIDEr score...
# CIDEr: 0.407
# loading annotations into memory...
# 0:00:00.353504
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23788, 'guess': [23180, 20190, 17200, 14210], 'testlen': 23180, 'correct': [17984, 9561, 4503, 1875]}
# ratio: 0.974440894569
# Bleu_1: 0.756
# Bleu_2: 0.590
# Bleu_3: 0.446
# Bleu_4: 0.327
# computing METEOR score...
# METEOR: 0.259
# computing Rouge score...
# ROUGE_L: 0.567
# computing CIDEr score...
# CIDEr: 0.372
# loading annotations into memory...
# 0:00:00.353612
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23497, 'guess': [22788, 19798, 16808, 13818], 'testlen': 22788, 'correct': [17864, 9486, 4400, 1781]}
# ratio: 0.969825935226
# Bleu_1: 0.760
# Bleu_2: 0.594
# Bleu_3: 0.447
# Bleu_4: 0.325
# computing METEOR score...
# METEOR: 0.256
# computing Rouge score...
# ROUGE_L: 0.564
# computing CIDEr score...
# CIDEr: 0.372
# loading annotations into memory...
# 0:00:00.413170
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23158, 'guess': [22550, 19560, 16570, 13580], 'testlen': 22550, 'correct': [17986, 9749, 4604, 1929]}
# ratio: 0.973745573884
# Bleu_1: 0.776
# Bleu_2: 0.614
# Bleu_3: 0.467
# Bleu_4: 0.345
# computing METEOR score...
# METEOR: 0.261
# computing Rouge score...
# ROUGE_L: 0.576
# computing CIDEr score...
# CIDEr: 0.389
# loading annotations into memory...
# 0:00:00.351127
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23879, 'guess': [23447, 20457, 17467, 14477], 'testlen': 23447, 'correct': [18353, 9755, 4546, 1865]}
# ratio: 0.98190879015
# Bleu_1: 0.768
# Bleu_2: 0.600
# Bleu_3: 0.451
# Bleu_4: 0.328
# computing METEOR score...
# METEOR: 0.258
# computing Rouge score...
# ROUGE_L: 0.568
# computing CIDEr score...
# CIDEr: 0.374
# loading annotations into memory...
# 0:00:00.355963
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 21760, 'guess': [20718, 17728, 14738, 11748], 'testlen': 20718, 'correct': [16965, 9483, 4601, 1912]}
# ratio: 0.952113970588
# Bleu_1: 0.779
# Bleu_2: 0.629
# Bleu_3: 0.490
# Bleu_4: 0.367
# computing METEOR score...
# METEOR: 0.263
# computing Rouge score...
# ROUGE_L: 0.588
# computing CIDEr score...
# CIDEr: 0.400
# loading annotations into memory...
# 0:00:00.346144
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23794, 'guess': [23202, 20212, 17222, 14232], 'testlen': 23202, 'correct': [18053, 9572, 4506, 1877]}
# ratio: 0.975119778095
# Bleu_1: 0.758
# Bleu_2: 0.592
# Bleu_3: 0.447
# Bleu_4: 0.327
# computing METEOR score...
# METEOR: 0.256
# computing Rouge score...
# ROUGE_L: 0.566
# computing CIDEr score...
# CIDEr: 0.376
# loading annotations into memory...
# 0:00:00.344607
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.11s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23557, 'guess': [22977, 19987, 16997, 14007], 'testlen': 22977, 'correct': [17869, 9488, 4451, 1878]}
# ratio: 0.975378868277
# Bleu_1: 0.758
# Bleu_2: 0.592
# Bleu_3: 0.448
# Bleu_4: 0.329
# computing METEOR score...
# METEOR: 0.257
# computing Rouge score...
# ROUGE_L: 0.568
# computing CIDEr score...
# CIDEr: 0.380
# loading annotations into memory...
# 0:00:00.344590
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23905, 'guess': [23406, 20416, 17426, 14436], 'testlen': 23406, 'correct': [18419, 10021, 4772, 2025]}
# ratio: 0.979125705919
# Bleu_1: 0.770
# Bleu_2: 0.608
# Bleu_3: 0.463
# Bleu_4: 0.342
# computing METEOR score...
# METEOR: 0.262
# computing Rouge score...
# ROUGE_L: 0.573
# computing CIDEr score...
# CIDEr: 0.390
# loading annotations into memory...
# 0:00:00.347252
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23128, 'guess': [22445, 19455, 16465, 13475], 'testlen': 22445, 'correct': [17854, 9675, 4627, 1956]}
# ratio: 0.970468695953
# Bleu_1: 0.772
# Bleu_2: 0.610
# Bleu_3: 0.466
# Bleu_4: 0.346
# computing METEOR score...
# METEOR: 0.259
# computing Rouge score...
# ROUGE_L: 0.572
# computing CIDEr score...
# CIDEr: 0.393
# loading annotations into memory...
# 0:00:00.343600
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 22102, 'guess': [21132, 18142, 15152, 12162], 'testlen': 21132, 'correct': [15538, 7251, 3042, 858]}
# ratio: 0.956112568998
# Bleu_1: 0.702
# Bleu_2: 0.518
# Bleu_3: 0.372
# Bleu_4: 0.243
# computing METEOR score...
# METEOR: 0.216
# computing Rouge score...
# ROUGE_L: 0.528
# computing CIDEr score...
# CIDEr: 0.164
# loading annotations into memory...
# 0:00:00.348178
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 21850, 'guess': [20788, 17798, 14808, 11818], 'testlen': 20788, 'correct': [16630, 8981, 4229, 1699]}
# ratio: 0.951395881007
# Bleu_1: 0.760
# Bleu_2: 0.604
# Bleu_3: 0.462
# Bleu_4: 0.341
# computing METEOR score...
# METEOR: 0.254
# computing Rouge score...
# ROUGE_L: 0.577
# computing CIDEr score...
# CIDEr: 0.356
# loading annotations into memory...
# 0:00:00.345786
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23882, 'guess': [23293, 20303, 17313, 14323], 'testlen': 23293, 'correct': [18063, 9578, 4497, 1909]}
# ratio: 0.975337073947
# Bleu_1: 0.756
# Bleu_2: 0.590
# Bleu_3: 0.445
# Bleu_4: 0.327
# computing METEOR score...
# METEOR: 0.258
# computing Rouge score...
# ROUGE_L: 0.564
# computing CIDEr score...
# CIDEr: 0.377
# loading annotations into memory...
# 0:00:00.347314
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 22575, 'guess': [21744, 18754, 15764, 12774], 'testlen': 21744, 'correct': [17477, 9584, 4621, 1981]}
# ratio: 0.963189368771
# Bleu_1: 0.774
# Bleu_2: 0.617
# Bleu_3: 0.475
# Bleu_4: 0.356
# computing METEOR score...
# METEOR: 0.264
# computing Rouge score...
# ROUGE_L: 0.580
# computing CIDEr score...
# CIDEr: 0.403
# loading annotations into memory...
# 0:00:00.345962
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 25024, 'guess': [24795, 21805, 18815, 15825], 'testlen': 24795, 'correct': [18973, 10087, 4741, 1975]}
# ratio: 0.990848785166
# Bleu_1: 0.758
# Bleu_2: 0.589
# Bleu_3: 0.443
# Bleu_4: 0.322
# computing METEOR score...
# METEOR: 0.258
# computing Rouge score...
# ROUGE_L: 0.562
# computing CIDEr score...
# CIDEr: 0.375
# loading annotations into memory...
# 0:00:00.346811
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23182, 'guess': [22434, 19444, 16454, 13464], 'testlen': 22434, 'correct': [17588, 9469, 4480, 1901]}
# ratio: 0.967733586403
# Bleu_1: 0.758
# Bleu_2: 0.598
# Bleu_3: 0.455
# Bleu_4: 0.337
# computing METEOR score...
# METEOR: 0.257
# computing Rouge score...
# ROUGE_L: 0.569
# computing CIDEr score...
# CIDEr: 0.378
# loading annotations into memory...
# 0:00:00.345390
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 24296, 'guess': [23945, 20955, 17965, 14975], 'testlen': 23945, 'correct': [18710, 10116, 4727, 1953]}
# ratio: 0.985553177478
# Bleu_1: 0.770
# Bleu_2: 0.605
# Bleu_3: 0.456
# Bleu_4: 0.332
# computing METEOR score...
# METEOR: 0.262
# computing Rouge score...
# ROUGE_L: 0.572
# computing CIDEr score...
# CIDEr: 0.385
# loading annotations into memory...
# 0:00:00.345435
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 22519, 'guess': [21709, 18719, 15729, 12739], 'testlen': 21709, 'correct': [17549, 9682, 4619, 1925]}
# ratio: 0.964030374351
# Bleu_1: 0.779
# Bleu_2: 0.623
# Bleu_3: 0.479
# Bleu_4: 0.356
# computing METEOR score...
# METEOR: 0.264
# computing Rouge score...
# ROUGE_L: 0.583
# computing CIDEr score...
# CIDEr: 0.401
# loading annotations into memory...
# 0:00:00.347060
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 22776, 'guess': [21956, 18966, 15976, 12986], 'testlen': 21956, 'correct': [17690, 9776, 4726, 2029]}
# ratio: 0.963997190025
# Bleu_1: 0.776
# Bleu_2: 0.621
# Bleu_3: 0.479
# Bleu_4: 0.359
# computing METEOR score...
# METEOR: 0.262
# computing Rouge score...
# ROUGE_L: 0.581
# computing CIDEr score...
# CIDEr: 0.404
# loading annotations into memory...
# 0:00:00.361028
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 22608, 'guess': [21772, 18782, 15792, 12802], 'testlen': 21772, 'correct': [17437, 9588, 4605, 1938]}
# ratio: 0.963021939137
# Bleu_1: 0.771
# Bleu_2: 0.615
# Bleu_3: 0.474
# Bleu_4: 0.353
# computing METEOR score...
# METEOR: 0.262
# computing Rouge score...
# ROUGE_L: 0.578
# computing CIDEr score...
# CIDEr: 0.394
# loading annotations into memory...
# 0:00:00.345402
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 21503, 'guess': [20276, 17286, 14296, 11306], 'testlen': 20276, 'correct': [16254, 8702, 4110, 1660]}
# ratio: 0.94293819467
# Bleu_1: 0.755
# Bleu_2: 0.598
# Bleu_3: 0.459
# Bleu_4: 0.340
# computing METEOR score...
# METEOR: 0.251
# computing Rouge score...
# ROUGE_L: 0.578
# computing CIDEr score...
# CIDEr: 0.352
# loading annotations into memory...
# 0:00:00.347507
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 21801, 'guess': [20746, 17756, 14766, 11776], 'testlen': 20746, 'correct': [16897, 9337, 4512, 1900]}
# ratio: 0.951607724416
# Bleu_1: 0.774
# Bleu_2: 0.622
# Bleu_3: 0.483
# Bleu_4: 0.362
# computing METEOR score...
# METEOR: 0.262
# computing Rouge score...
# ROUGE_L: 0.584
# computing CIDEr score...
# CIDEr: 0.390
# loading annotations into memory...
# 0:00:00.348127
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23271, 'guess': [22597, 19607, 16617, 13627], 'testlen': 22597, 'correct': [17860, 9703, 4529, 1865]}
# ratio: 0.971036912896
# Bleu_1: 0.767
# Bleu_2: 0.607
# Bleu_3: 0.460
# Bleu_4: 0.337
# computing METEOR score...
# METEOR: 0.259
# computing Rouge score...
# ROUGE_L: 0.571
# computing CIDEr score...
# CIDEr: 0.392
# loading annotations into memory...
# 0:00:00.346490
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 21944, 'guess': [20846, 17856, 14866, 11876], 'testlen': 20846, 'correct': [16503, 8690, 4093, 1610]}
# ratio: 0.949963543565
# Bleu_1: 0.751
# Bleu_2: 0.589
# Bleu_3: 0.449
# Bleu_4: 0.329
# computing METEOR score...
# METEOR: 0.252
# computing Rouge score...
# ROUGE_L: 0.576
# computing CIDEr score...
# CIDEr: 0.342
# loading annotations into memory...
# 0:00:00.364367
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23682, 'guess': [23119, 20129, 17139, 14149], 'testlen': 23119, 'correct': [18015, 9525, 4442, 1809]}
# ratio: 0.976226670045
# Bleu_1: 0.760
# Bleu_2: 0.593
# Bleu_3: 0.446
# Bleu_4: 0.324
# computing METEOR score...
# METEOR: 0.255
# computing Rouge score...
# ROUGE_L: 0.562
# computing CIDEr score...
# CIDEr: 0.373
# loading annotations into memory...
# 0:00:00.353802
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 22804, 'guess': [22008, 19018, 16028, 13038], 'testlen': 22008, 'correct': [17315, 9239, 4346, 1851]}
# ratio: 0.965093843185
# Bleu_1: 0.759
# Bleu_2: 0.596
# Bleu_3: 0.453
# Bleu_4: 0.336
# computing METEOR score...
# METEOR: 0.258
# computing Rouge score...
# ROUGE_L: 0.567
# computing CIDEr score...
# CIDEr: 0.378
# loading annotations into memory...
# 0:00:00.349672
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 23743, 'guess': [23248, 20258, 17268, 14278], 'testlen': 23248, 'correct': [18230, 9777, 4547, 1857]}
# ratio: 0.979151749989
# Bleu_1: 0.768
# Bleu_2: 0.602
# Bleu_3: 0.454
# Bleu_4: 0.330
# computing METEOR score...
# METEOR: 0.259
# computing Rouge score...
# ROUGE_L: 0.569
# computing CIDEr score...
# CIDEr: 0.377
# loading annotations into memory...
# 0:00:00.365698
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 24722, 'guess': [24418, 21428, 18438, 15448], 'testlen': 24418, 'correct': [18843, 9979, 4683, 1902]}
# ratio: 0.987703260254
# Bleu_1: 0.762
# Bleu_2: 0.592
# Bleu_3: 0.445
# Bleu_4: 0.322
# computing METEOR score...
# METEOR: 0.257
# computing Rouge score...
# ROUGE_L: 0.564
# computing CIDEr score...
# CIDEr: 0.377
# loading annotations into memory...
# 0:00:00.351485
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 24055, 'guess': [23573, 20583, 17593, 14603], 'testlen': 23573, 'correct': [18398, 9690, 4555, 1908]}
# ratio: 0.979962585741
# Bleu_1: 0.765
# Bleu_2: 0.594
# Bleu_3: 0.447
# Bleu_4: 0.327
# computing METEOR score...
# METEOR: 0.260
# computing Rouge score...
# ROUGE_L: 0.565
# computing CIDEr score...
# CIDEr: 0.377
# loading annotations into memory...
# 0:00:00.384550
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# tokenization...
# setting up scorers...
# computing Bleu score...
# {'reflen': 21390, 'guess': [20261, 17271, 14281, 11291], 'testlen': 20261, 'correct': [16582, 9183, 4407, 1837]}
# ratio: 0.947218326321
# Bleu_1: 0.774
# Bleu_2: 0.624
# Bleu_3: 0.484
# Bleu_4: 0.364
# computing METEOR score...
# METEOR: 0.259
# computing Rouge score...
# ROUGE_L: 0.585
# computing CIDEr score...
# CIDEr: 0.391

# %%
import pickle
import numpy as np

# %%
with open(os.path.join(data_config["result_dir"],"scores.pkl"),"wb") as fl:
            pickle.dump(scores,fl)

# %%
table = {"model":[],"Bleu_1":[],"Bleu_2":[],"Bleu_3":[],"Bleu_4":[],"METEOR":[],"ROUGE_L":[],"CIDEr":[]}
table["model"] = [i[0] for i in c]
table["Bleu_1"] = [i[1]["Bleu_1"] for i in c]
table["Bleu_2"] = [i[1]["Bleu_2"] for i in c]
table["Bleu_3"] = [i[1]["Bleu_3"] for i in c]
table["Bleu_4"] = [i[1]["Bleu_4"] for i in c]
table["METEOR"] = [i[1]["METEOR"] for i in c]
table["ROUGE_L"] = [i[1]["ROUGE_L"] for i in c]
table["CIDEr"] = [i[1]["CIDEr"] for i in c]
df = pd.DataFrame(table)
plt.figure()

df.plot(x='model',marker='o',title="Captioning Scores")
plt.legend(loc='best')
plt.yticks(np.arange(0.2, 1.0, 0.05))
# Out:
# ([<matplotlib.axis.YTick at 0x7fd5e026da10>,
#   <matplotlib.axis.YTick at 0x7fd5e026dd10>,
#   <matplotlib.axis.YTick at 0x7fd5e3002310>,
#   <matplotlib.axis.YTick at 0x7fd5e3002bd0>,
#   <matplotlib.axis.YTick at 0x7fd5e2ff92d0>,
#   <matplotlib.axis.YTick at 0x7fd5e3002490>,
#   <matplotlib.axis.YTick at 0x7fd5df0f83d0>,
#   <matplotlib.axis.YTick at 0x7fd5e2ff9990>,
#   <matplotlib.axis.YTick at 0x7fd5e2a410d0>,
#   <matplotlib.axis.YTick at 0x7fd5ef79e9d0>,
#   <matplotlib.axis.YTick at 0x7fd5e2db40d0>,
#   <matplotlib.axis.YTick at 0x7fd5e2db4710>,
#   <matplotlib.axis.YTick at 0x7fd5e2db4dd0>,
#   <matplotlib.axis.YTick at 0x7fd5ee77c510>,
#   <matplotlib.axis.YTick at 0x7fd5ee77cc10>,
#   <matplotlib.axis.YTick at 0x7fd5ea0dd350>],
#  <a list of 16 Text yticklabel objects>)

# %%
figure = plt.gcf()
figure.set_size_inches(20, 14)
plt.savefig(os.path.join(data_config["result_dir"],"graph.png"))

# %%
plt.close()

# %%
with open(os.path.join(data_config["result_dir"],"result.csv"),"w") as fl:
    fl.write("%15s , %8s , %8s , %8s , %8s , %8s , %8s , %8s\n" 
            %("model","Bleu_1","Bleu_2","Bleu_3","Bleu_4","METEOR","ROUGE_L","CIDEr"))

    for model,data in c:
        fl.write("%15s , %8.3f , %8.3f , %8.3f , %8.3f , %8.3f , %8.3f , %8.3f\n"
                                                                %(model,data["Bleu_1"],
                                                                data["Bleu_2"],data["Bleu_3"],
                                                                data["Bleu_4"],data["METEOR"],
                                                                data["ROUGE_L"],data["CIDEr"]))
